# %%
import pandas as pd  # Biblioteca para manipulação de dados em formato de tabelas (DataFrames)
import numpy as np  # Biblioteca para cálculos numéricos
import matplotlib.pyplot as plt  # Biblioteca para criação de gráficos
from sklearn.linear_model import LinearRegression  # Importa o modelo de regressão linear
from sklearn.model_selection import train_test_split  # Função para dividir dados em treino e teste
from sklearn.metrics import mean_squared_error, r2_score  # Funções para avaliar o modelo

# %%
df = pd.read_csv("sorvete-temperatura.csv")
df
# Out:
#     Temperatura_Media_Diaria_C  Unidades_Sorvete_Vendidas
# 0                           30                         42
# 1                           16                          6
# 2                           35                         65
# 3                           18                          7
# 4                           27                         35
# 5                           20                         18
# 6                           21                         19
# 7                           22                          1
# 8                           23                          1
# 9                           24                         11
# 10                          25                         25
# 11                          26                         12
# 12                          27                         13
# 13                          28                         14
# 14                          29                         25
# 15                          30                         36
# 16                          31                         37
# 17                          32                         42
# 18                          33                         49
# 19                          34                         52

# %%
# -------------------------------------
# 3. Separar os dados em X e y
# -------------------------------------
X = df[["Temperatura_Media_Diaria_C"]]  # Seleciona a coluna 'Experiencia' como entrada (precisa ser 2D)
y = df["Unidades_Sorvete_Vendidas"]  # Seleciona a coluna 'Salario' como saída

# %%
# 4. Dividir os dados em treino e teste
# -------------------------------------
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# -------------------------------------
# 5. Criar e treinar o modelo
# -------------------------------------
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# -------------------------------------
# 6. Fazer previsões
# -------------------------------------
y_pred = modelo.predict(X_test)

# %%
# -------------------------------------
# 7. Avaliar o modelo
# -------------------------------------
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"\nErro médio quadrático (MSE): {mse:.2f}")
print(f"Raiz do erro médio quadrático (RMSE): {rmse:.2f}")
print(f"Coeficiente de determinação (R²): {r2:.2f}")
# Out:
# Erro médio quadrático (MSE): 1022.67
# Raiz do erro médio quadrático (RMSE): 31.98
# Coeficiente de determinação (R²): -2.65

# %%
# -------------------------------------
# 8. Fazer previsão para um novo valor
# -------------------------------------
experiencia_teste = [[35]]
sorvete_previsto = modelo.predict(experiencia_teste)
print(f"\nPara 35° Graus, a previsão de vendas de Sorvete é: {sorvete_previsto[0]:.2f}")
# Out:
# Para 35° Graus, a previsão de vendas de Sorvete é: 51.66
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# -------------------------------------
# 9. Visualizar a reta de regressão
# -------------------------------------
plt.figure(figsize=(8, 5))
plt.scatter(X, y, color="blue", label="Vendas")
plt.plot(X, modelo.predict(X), color="red", label="Reta de regressão")
plt.xlabel("Temperatura")
plt.ylabel("Sorvete")
plt.title("Regressão Linear Simples")
plt.legend()
plt.grid(True)
plt.show()
