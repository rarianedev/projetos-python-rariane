# %%
frutas = ['maçã', 'banana', 'laranja', 'uva']
#1 
print(frutas[0], frutas[-1])
# Out:
# maçã uva

# %%
#2
print(frutas[:3])
# Out:
# ['maçã', 'banana', 'laranja']

# %%
#3
frutas.append('kiwi')
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'kiwi']

# %%
#4
frutas.insert(-1, 'uva')
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'uva', 'kiwi']

# %%
#5
frutas.remove('abacate')
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'kiwi']

# %%
#6
item = frutas.pop()
print(item)
print(frutas)
# Out:
# kiwi
# ['maçã', 'banana', 'laranja']

# %%
#7
pos = frutas.index('banana')
print(pos)
# Out:
# 1

# %%
#8
frutas.sort()
print(frutas)
# Out:
# ['banana', 'kiwi', 'laranja', 'maçã', 'uva']

# %%
#9
frutas.sort(reverse=True)
print(frutas)
# Out:
# ['uva', 'maçã', 'laranja', 'kiwi', 'banana']

# %%
#10
print("banana" in frutas)
# Out:
# True
