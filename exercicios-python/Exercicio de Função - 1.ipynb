# %%
#1. Crie uma função chamada saudacao() que exiba 'Bem-vindo(a)!'. 
#Explicação: Use a palavra-chave def para definir a função e dentro dela use print para exibir 
#a mensagem. 

def saudacao():
    print('Bem Vindo(a)!')
saudacao()
# Out:
# Bem Vindo(a)!

# %%
#2. Crie uma função chamada ola(nome) que receba um nome e exiba 'Olá, nome!'. 
#Explicação: A função precisa de um parâmetro 'nome' e deve usar f-string para formatar a 
#mensagem.
def ola(nome):
    print('Ola! {}'.format(nome))

ola(input('Nome: '))
# Out:
# Nome:  rari
# Ola! rari

# %%
#3. Crie uma função chamada dobro(n) que receba um número e retorne o dobro dele. 
#Explicação: A função deve receber um valor, multiplicar por 2 e retornar o resultado com 
#return. 
def dobro(n):
    return print('O dobro de {} é {}'.format(n, n*2))

dobro(float(input('Informe uma valor: ')))
# Out:
# Informe uma valor:  3
# O dobro de 3.0 é 6.0

# %%
#4. Crie uma função soma(a, b) que some dois números e retorne o resultado. 
#Explicação: Defina dois parâmetros e use return para devolver a soma dos dois valores. 
def soma(a,b):
    return print('A soma de {} e {} é {}'.format(a,b,a+b))

soma(int(input('Informe o valor a: ')), int(input('Informe o valor b: ')))
# Out:
# Informe o valor a:  2
# Informe o valor b:  3
# A soma de 2 e 3 é 5

# %%
#5. Crie uma função eh_par(n) que verifique se o número é par. 
#Explicação: Use o operador % para verificar se n % 2 == 0 e retorne True ou False. 
def par(n):
    if n%2==0:
        print('{} é par.'.format(n))
    else:
        print('{} é ímpar.'.format(n))
par(int(input('Informe um valor: ')))
# Out:
# Informe um valor:  3
# 3 é ímpar.

# %%
#calcular a area do triangulo = base*altura/2
#calcular o retangulo = base*altura
#losangulo = diagonal menor*diagonal maior/2
#circulo = 3.14*raio**2
#trapézio = ((base maior+base menor)*altura)/2
#quadrado = lado**2

# %%
def menu():
    print("\n1. Calcular a Area do Triangulo")
    print("2. Calcular a Area do Quadrado")
    print("3. Calcular a Area do Losangulo")
    print("4. Calcular a Area do Circulo")
    print("5. Calcular a Area do Trapezio")
    print("6. Calcular a Area do Retangulo")

while True:
    menu()
    escolha = input("Escolha uma opção: ")
    if escolha == '1':
        area_triangulo()
        
    elif escolha == '2':
        area_quadrado()
        
    elif escolha == '3':
        area_losangulo()
        
    elif escolha == '4':
        area_circulo()
        
    elif escolha == '5':
        area_trapezio()
        
    elif escolha == '6':
        area_retangulo()
        
    else:
        print("Opção inválida. Por favor, escolha uma opção válida.")
        break
    voltar = input('Você deseja continuar?')
    if voltar == 'sim':
        menu()
    else: 
        break
    
def area_triangulo():
    base = float(input('Informe a base do triangulo: '))
    altura = float(input('Informe a altura do triangulo: '))
    area = base*altura
    print('A area do triangulo é {}'.format(area))
    
def area_quadrado():
    base = float(input('Informe a base do quadrado: '))
    area = base**2
    print('A area do quadrado: {}'.format(area))

def area_losangulo():
    diag_menor = float(input('Informe a diagonal menor: '))
    diag_maior = float(input('Informe a diagonal maior: '))
    area = (diag_menor*diag_maior)/2
    print('A area do losangulo: {}'.format(area))

def area_circulo():
    raio = float(input('Informe o raio do circulo: '))
    area = 3.14*raio**2
    print('A area do circulo: {}'.format(area))

def area_trapezio():
    base_menor = float(input('Informe a base menor: '))
    base_maior = float(input('Informe a base maior: '))
    altura = float(input('Informe a altura: '))
    area = ((base_maior+base_menor)*altura)/2
    print('A area do trapezio é {}'.format(area))

def area_retangulo():
    altura = float(input('Informe a altura: '))
    base = float(input('Informe a base: '))
    area = base*altura
    print('A area do retangulo é {}'.format(area))
# Out:
# 1. Calcular a Area do Triangulo
# 2. Calcular a Area do Quadrado
# 3. Calcular a Area do Losangulo
# 4. Calcular a Area do Circulo
# 5. Calcular a Area do Trapezio
# 6. Calcular a Area do Retangulo
# Escolha uma opção:  2
# Informe a base do quadrado:  4
# A area do quadrado: 16.0
# Você deseja continuar? nao

# %%
def area_triangulo():
    base = float(input('Informe a base do triangulo: '))
    altura = float(input('Informe a altura do triangulo: '))
    area = base*altura
    print('A area do triangulo é {}'.format(area))

area_triangulo()
# Out:
# Informe a base do triangulo:  4
# Informe a altura do triangulo:  5
# A area do triangulo é 20.0

# %%
def area_quadrado():
    base = float(input('Informe a base do quadrado: '))
    area = base**2
    print('A area do quadrado: {}'.format(area))

area_quadrado()
# Out:
# Informe a base do quadrado:  5
# A area do quadrado: 25.0

# %%
def area_losangulo():
    diag_menor = float(input('Informe a diagonal menor: '))
    diag_maior = float(input('Informe a diagonal maior: '))
    area = (diag_menor*diag_maior)/2
    print('A area do losangulo: {}'.format(area))

area_losangulo()
# Out:
# Informe a diagonal menor:  6
# Informe a diagonal maior:  4
# A area do losangulo: 12.0

# %%
def area_circulo():
    raio = float(input('Informe o raio do circulo: '))
    area = 3.14*raio**2
    print('A area do circulo: {}'.format(area))
area_circulo()
# Out:
# Informe o raio do circulo:  7
# A area do circulo: 153.86

# %%
def area_trapezio():
    base_menor = float(input('Informe a base menor: '))
    base_maior = float(input('Informe a base maior: '))
    altura = float(input('Informe a altura: '))
    area = ((base_maior+base_menor)*altura)/2
    print('A area do trapezio é {}'.format(area))

area_trapezio()
# Out:
# Informe a base menor:  3
# Informe a base maior:  3
# Informe a altura:  3
# A area do trapezio é 9.0

# %%
def area_retangulo():
    altura = float(input('Informe a altura: '))
    base = float(input('Informe a base: '))
    area = base*altura
    print('A area do retangulo é {}'.format(area))

area_retangulo()
# Out:
# Informe a altura:  4
# Informe a base:  5
# A area do retangulo é 20.0

# %%
#. Crie uma função que retorne o comprimento de uma string. 
#Explicação: Receba a string como parâmetro e use a função len para retornar seu tamanho.

def compri(nome):
    return len(nome)
compri('Rari')
# Out:
# 4

# %%
#7. Crie uma função maior_valor(lista) que retorne o maior número de uma lista. 
#Explicação: Use a função max() sobre a lista recebida como parâmetro. 
def maior_valor(lista):
    return print(max(lista))
maior_valor([12, 13, 14, 15])
# Out:
# 15

# %%
#8. Crie uma função media(lista) que retorne a média dos elementos. 
#Explicação: Some os elementos com sum() e divida por len(lista). 
def media_da_lista(lista):
    media = sum(lista)/len(lista)
    return media

media_da_lista([10,12,14,15])
# Out:
# 12.75

# %%
#9. Crie uma função contar_letra(texto, letra) que conte quantas vezes uma letra aparece em 
#um texto. 
#Explicação: Use o método count() da string. 

def contar_letra(texto,letra):
    return texto.count(letra)
    
contar_letra('curso python', 'o')
# Out:
# 2

# %%
#10. Crie uma função inverte(texto) que retorne o texto ao contrário. 
#Explicação: Use fatiamento com texto[::-1] para inverter. 

def inverte(texto):
    return texto[::-1]

inverte('Abd')
# Out:
# 'dbA'

# %%
#11. Crie uma função multiplicar_lista(lista, n) que multiplica todos os elementos por n. 
#Explicação: Use um laço for para multiplicar cada item da lista pelo valor n e retorne uma 
#nova lista. 

def multiplicar_lista(lista,n):
    for i in lista:
        multi = i*n
    return multi

multiplicar_lista([1,2,3,4,5], 2)
# Out:
# 10
