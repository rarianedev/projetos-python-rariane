# %%
# Etapa 1 — Importação de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
# 📥 Carregamento inicial do dataset
df = pd.read_csv("dataset_produtividade_guarana.csv", sep=';', decimal=',')
df
# Out:
#      ano  chuva_durante_floração_mm  chuva_durante_colheita_mm  \
# 0   1984                      423.2                      516.7
# 1   1985                      363.0                      540.0
# 2   1986                      320.6                      666.9
# 3   1987                      360.0                      180.4
# 4   1988                      419.4                      693.8
# 5   1989                      480.9                      454.1
# 6   1990                      657.5                      399.6
# 7   1991                      454.5                      125.3
# 8   1992                      557.5                       39.7
# 9   1993                      380.3                      401.2
# 10  1994                      382.3                      549.8
# 11  1995                      200.4                      613.1
# 12  1996                      260.6                      490.6
# 13  1997                      132.6                      487.9
# 14  1998                      276.7                      363.8
# 15  1999                      221.8                      582.8
# 16  2000                      267.1                      355.7
# 17  2001                      441.3                      240.8
# 18  2002                      304.1                      506.2
# 19  2003                      288.8                      229.1
# 20  2004                      282.6                      363.2
# 21  2005                      201.6                      405.9
# 22  2006                      191.6                      258.4
# 23  2007                      363.2                      413.1
# 24  2008                      430.0                      737.1
# 25  2009                      315.5                      458.2
# 26  2010                      314.4                      490.8
# 27  2011                      371.9                      579.4
# 28  2012                      391.9                      637.5
# 29  2013                      376.0                      495.3
# 30  2014                      428.9                      744.6
# 31  2015                      332.7                      252.3
# 32  2016                      308.7                      726.4
# 33  2017                      361.8                      564.2
# 34  2018                      427.7                      449.4
# 35  2019                      283.0                      756.9
# 36  2020                      330.1                      549.9
# 37  2021                      390.4                      663.0
# 38  2022                      482.8                      488.1
# 39  2023                      227.0                      215.8
#
#     chuva_total_anual_mm  anomalia_chuva_floração_mm  \
# 0                 2459.8                        93.4
# 1                 2773.6                        33.2
# 2                 2694.5                        -9.2
# 3                 2165.2                        30.2
# 4                 2932.8                        89.6
# 5                 2416.7                       151.1
# 6                 2732.2                       327.7
# 7                 2332.2                       124.7
# 8                 1889.4                       227.7
# 9                 2250.9                        50.5
# 10                2592.3                        52.5
# 11                2184.7                      -129.4
# 12                2728.6                       -69.2
# 13                1952.5                      -197.2
# 14                2309.7                       -53.1
# 15                2987.7                      -108.0
# 16                2638.8                       -62.7
# 17                2244.8                       111.5
# 18                2378.3                       -25.7
# 19                2130.8                       -41.0
# 20                2472.3                       -47.2
# 21                1933.4                      -128.2
# 22                2343.8                      -138.2
# 23                2466.6                        33.4
# 24                3073.9                       100.2
# 25                2644.6                       -14.3
# 26                1940.6                       -15.4
# 27                3432.9                        42.1
# 28                2825.3                        62.1
# 29                2714.0                        46.2
# 30                3020.9                        99.1
# 31                2239.9                         2.9
# 32                2988.5                       -21.1
# 33                2831.5                        32.0
# 34                2456.5                        97.9
# 35                2965.2                       -46.8
# 36                2212.3                         0.3
# 37                3033.3                        60.6
# 38                2970.3                       153.0
# 39                1950.6                      -102.8
#
#     temperatura_média_floração_C  umidade_relativa_média_floração_%  \
# 0                          26.16                              84.25
# 1                          25.78                              84.09
# 2                          25.46                              84.24
# 3                          26.91                              86.56
# 4                          27.80                              85.59
# 5                          26.78                              86.53
# 6                          26.67                              86.80
# 7                          26.05                              86.10
# 8                          27.21                              83.73
# 9                          26.85                              86.84
# 10                         24.83                              86.25
# 11                         27.55                              85.40
# 12                         26.92                              87.87
# 13                         27.88                              78.49
# 14                         27.81                              82.51
# 15                         27.08                              83.65
# 16                         24.99                              85.10
# 17                         26.43                              85.28
# 18                         27.30                              83.21
# 19                         27.48                              82.96
# 20                         27.23                              82.69
# 21                         27.37                              85.14
# 22                         27.05                              85.30
# 23                         27.53                              80.09
# 24                         27.36                              80.58
# 25                         28.00                              78.91
# 26                         28.16                              76.95
# 27                         28.19                              76.11
# 28                         27.75                              77.90
# 29                         27.75                              79.45
# 30                         28.07                              78.82
# 31                         28.55                              82.82
# 32                         28.45                              77.09
# 33                         28.55                              74.68
# 34                         27.70                              77.44
# 35                         28.19                              76.03
# 36                         28.63                              79.21
# 37                         27.72                              78.46
# 38                         27.82                              76.90
# 39                         28.51                              80.69
#
#    evento_ENSO  produtividade_kg_por_ha produtividade_safra
# 0       Neutro                      110               media
# 1       Neutro                      107               media
# 2      El Niño                      109               media
# 3      El Niño                       74               baixa
# 4      La Niña                      102               media
# 5       Neutro                       51               baixa
# 6       Neutro                       52               baixa
# 7      El Niño                      120               media
# 8       Neutro                      124                alta
# 9       Neutro                       50               baixa
# 10     El Niño                       50               baixa
# 11     La Niña                       50               baixa
# 12      Neutro                       95               media
# 13     El Niño                       95               media
# 14     La Niña                      100               media
# 15     La Niña                      399                alta
# 16     La Niña                      250                alta
# 17      Neutro                      101               media
# 18     El Niño                      150                alta
# 19      Neutro                      151                alta
# 20     El Niño                      150                alta
# 21      Neutro                      250                alta
# 22      Neutro                      208                alta
# 23     La Niña                      208                alta
# 24      Neutro                       63               baixa
# 25     El Niño                      196                alta
# 26     La Niña                      249                alta
# 27     La Niña                      250                alta
# 28      Neutro                      160                alta
# 29      Neutro                      125                alta
# 30      Neutro                      142                alta
# 31     El Niño                      122                alta
# 32     La Niña                      122                alta
# 33      Neutro                      140                alta
# 34      Neutro                      100               media
# 35      Neutro                      157                alta
# 36     La Niña                      160                alta
# 37     La Niña                      130                alta
# 38     La Niña                      130                alta
# 39     El Niño                       90               media

# %%
# X -> múltiplas variáveis
X = df[['chuva_durante_floração_mm', 'chuva_durante_colheita_mm','chuva_total_anual_mm', 'temperatura_média_floração_C', 'anomalia_chuva_floração_mm', 'temperatura_média_floração_C', 'umidade_relativa_média_floração_%']]

# y -> Preço
y = df['produtividade_kg_por_ha']

X.head()
# Out:
#    chuva_durante_floração_mm  chuva_total_anual_mm  \
# 0                      423.2                2459.8
# 1                      363.0                2773.6
# 2                      320.6                2694.5
# 3                      360.0                2165.2
# 4                      419.4                2932.8
#
#    temperatura_média_floração_C
# 0                         26.16
# 1                         25.78
# 2                         25.46
# 3                         26.91
# 4                         27.80

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
modelo = LinearRegression()
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Calcular a matriz de covariância
covariance_matrix = df[['chuva_durante_floração_mm', 'chuva_durante_colheita_mm','chuva_total_anual_mm', 'temperatura_média_floração_C', 'anomalia_chuva_floração_mm', 'temperatura_média_floração_C', 'umidade_relativa_média_floração_%']].cov()

# Criar o gráfico de heatmap das covariâncias
plt.figure(figsize=(10, 8))
sns.heatmap(covariance_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Heatmap das Covariâncias')
plt.show()

# %%
#Agora iremos atribuir a variável Gold price para Y e as demais para X

Y = df['produtividade_kg_por_ha']
X = df[['chuva_durante_floração_mm', 'chuva_durante_colheita_mm','chuva_total_anual_mm', 'temperatura_média_floração_C', 'anomalia_chuva_floração_mm', 'temperatura_média_floração_C', 'umidade_relativa_média_floração_%']]

# Agora iremos adicionar uma constante ao modelo
X = sm.add_constant(X)

# Com o próprio stats model iremos criar o modelo de regressão linear
modelo = sm.OLS(Y, X).fit()
# Visualizando os resultados
print(modelo.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     produtividade_kg_por_ha   R-squared:                       0.321
# Model:                                 OLS   Adj. R-squared:                  0.221
# Method:                      Least Squares   F-statistic:                     3.216
# Date:                     Wed, 04 Jun 2025   Prob (F-statistic):             0.0175
# Time:                             11:05:40   Log-Likelihood:                -218.99
# No. Observations:                       40   AIC:                             450.0
# Df Residuals:                           34   BIC:                             460.1
# Df Model:                                5
# Covariance Type:                 nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 0.0149      0.013      1.111      0.274      -0.012       0.042
# chuva_durante_floração_mm             2.2777      2.210      1.030      0.310      -2.214       6.770
# chuva_durante_colheita_mm            -0.1788      0.086     -2.086      0.045      -0.353      -0.005
# chuva_total_anual_mm                  0.0889      0.041      2.168      0.037       0.006       0.172
# temperatura_média_floração_C         -4.1769      7.632     -0.547      0.588     -19.687      11.333
# anomalia_chuva_floração_mm           -2.6364      2.214     -1.191      0.242      -7.136       1.863
# temperatura_média_floração_C         -4.1769      7.632     -0.547      0.588     -19.687      11.333
# umidade_relativa_média_floração_%    -6.3423      4.147     -1.529      0.135     -14.769       2.085
# ==============================================================================
# Omnibus:                       18.188   Durbin-Watson:                   1.645
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.833
# Skew:                           1.401   Prob(JB):                     6.68e-06
# Kurtosis:                       5.539   Cond. No.                     3.03e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.02e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
df['Y_previsto_statsmodels'] = modelo.predict(X)

# Plotando valores reais versus previstos
plt.figure(figsize=(10, 6))
plt.scatter(df['chuva_total_anual_mm'], df['produtividade_kg_por_ha'], label='Real', color='blue')
plt.scatter(df['chuva_total_anual_mm'], df['Y_previsto_statsmodels'], label='Previsto', color='red')
plt.title('Valores Reais vs. Previstos - Gold_Price')
plt.xlabel('chuva_total_anual_mm')
plt.ylabel('produtividade_kg_por_ha')
plt.legend()
plt.show()

# %%
Y_previsto = df['Y_previsto_statsmodels']
Y_real = df['produtividade_kg_por_ha']

# Calcula o MAE
mae = mean_absolute_error(Y_real, Y_previsto)

print(f"MAE: {mae}")
# Out:
# MAE: 43.41591574210408

# %%
modelo = sm.OLS(df['produtividade_kg_por_ha'], sm.add_constant(df[['chuva_durante_floração_mm', 'chuva_durante_colheita_mm','chuva_total_anual_mm', 'temperatura_média_floração_C', 'anomalia_chuva_floração_mm', 'temperatura_média_floração_C', 'umidade_relativa_média_floração_%']])).fit()

# Calcular os resíduos
residuos = modelo.resid

# Visualizar os resíduos
# Gráfico de dispersão dos resíduos
plt.figure(figsize=(8, 6))
plt.scatter(df['produtividade_kg_por_ha'], residuos)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Gráfico de dispersão dos resíduos')
plt.xlabel('Valores previstos')
plt.ylabel('Resíduos')
plt.show()

# %%
#variáveis de classificação
